# %%
import pandas as pd

# %%
reviews_df = pd.read_csv('../data/reviews.csv')
recipes_df = pd.read_csv('../data/cleaned_recipes.csv')

# %%
recipes_df.head()
# Out:
#    Unnamed: 0  RecipeId                                        Name  AuthorId  \
# 0           0        38           Low-Fat Berry Blue Frozen Dessert      1533
# 1           4        42                                Cabbage Soup      1538
# 2           7        45  Buttermilk Pie With Gingersnap Crumb Crust      1580
# 3           8        46                     A Jad - Cucumber Pickle      1533
# 4           9        47                        Butter Pecan Cookies      1573
#
#   AuthorName CookTime PrepTime TotalTime         DatePublished  \
# 0     Dancer    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1  Duckie067    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
# 2  tristitia    PT50M    PT30M   PT1H20M  1999-08-06T00:40:00Z
# 3     Dancer      NaN    PT25M     PT25M  1999-08-11T19:48:00Z
# 4     benluc     PT9M    PT55M    PT1H4M  1999-09-07T09:01:00Z
#
#                                               Images  ... Calories FatContent  \
# ...

# %%
reviews_df.head()
# Out:
#    ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0         2       992      2008         gayg msft       5
# 1         7      4384      1634     Bill Hilbrich       4
# 2         9      4523      2046  Gay Gilmore ckpt       2
# 3        13      7435      1773     Malarkey Test       5
# 4        14        44      2085        Tony Small       5
#
#                                               Review         DateSubmitted  \
# 0       better than any you can get at a restaurant!  2000-01-25T21:44:00Z
# 1  I cut back on the mayo, and made up the differ...  2001-10-17T16:49:59Z
# 2  i think i did something wrong because i could ...  2000-02-25T09:00:00Z
# 3  easily the best i have ever had.  juicy flavor...  2000-03-13T21:15:00Z
# 4                                 An excellent dish.  2000-03-28T12:51:00Z
#
#            DateModified
# 0  2000-01-25T21:44:00Z
# 1  2001-10-17T16:49:59Z
# 2  2000-02-25T09:00:00Z
# 3  2000-03-13T21:15:00Z
# 4  2000-03-28T12:51:00Z

# %%
reviews_df.isnull().sum()
# Out:
# ReviewId           0
# RecipeId           0
# AuthorId           0
# AuthorName         0
# Rating             0
# Review           214
# DateSubmitted      0
# DateModified       0
# dtype: int64

# %%
reviews_df.dtypes
# Out:
# ReviewId          int64
# RecipeId          int64
# AuthorId          int64
# AuthorName       object
# Rating            int64
# Review           object
# DateSubmitted    object
# DateModified     object
# dtype: object

# %%
print(reviews_df['Rating'].unique())
# Out:
# [5 4 2 0 1 3]

# %%
merged_df = recipes_df.merge(reviews_df, on='RecipeId', how='outer', copy=True)

# %%
indices = merged_df.groupby('RecipeCategory')['Rating'].idxmax()

# %%
indices
# Out:
# RecipeCategory
# Breakfast          571
# Cuisine           2079
# Dessert              0
# Diet               560
# Dinner             273
# Holiday/Event    70575
# Ingredients         16
# Lunch              595
# Misc                80
# Time               942
# Name: Rating, dtype: int64

# %%
merged_df.iloc[571]
# Out:
# Unnamed: 0                                                                 43.0
# RecipeId                                                                     83
# Name                                                          Bubble and Squeak
# AuthorId_x                                                               1544.0
# AuthorName_x                                                             tranch
# CookTime                                                                PT2H27M
# PrepTime                                                                  PT30M
# TotalTime                                                               PT2H57M
# DatePublished                                              1999-08-28T02:59:00Z
# Images                                                             character(0)
# RecipeCategory                                                        Breakfast
# Keywords                      c("European", "Weeknight", "Broil/Grill", "Ove...
# ...

# %%
recipes = merged_df.iloc[indices][['Name', 'RecipeInstructions', 'RecipeIngredientParts', 'RecipeIngredientQuantities', 'RecipeCategory', 'Images', 'Calories', 'FatContent', 'SaturatedFatContent', 'CholesterolContent', 'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent']]

# %%
d = recipes.to_dict()

# %%
len(d)
# Out:
# 15

# %%
len(recipes)
# Out:
# 10

# %%
recipes
# Out:
#                                                 Name  \
# 571                                Bubble and Squeak
# 2079   Spaetzle - Basic Recipe - Art Culinaire Issue
# 0                  Low-Fat Berry Blue Frozen Dessert
# 560                        Buttermilk Ranch Dressing
# 273           Low-Fat Burgundy Beef & Vegetable Stew
# 70575                            Poseidon's Scallops
# 16                                      Cabbage Soup
# 595                   Brown Rice and Vegetable Pilaf
# 80                                   Cafe Cappuccino
# 942                Appetizers-Easy Stuffed Mushrooms
#
#                                       RecipeInstructions  \
# 571    c("Wash potatoes under cold running water then...
# 2079   c("Bring a saucepan of salted water it a boil,...
# 0      c("Toss 2 cups berries with sugar.", "Let stan...
# 560    c("Mash together garlic and salt to form a pas...
# 273    c("Trim fat from beef, cut into 1-inch pieces....
# ...

# %%
recipes.reset_index(drop=True)
# Out:
#                                             Name  \
# 0                              Bubble and Squeak
# 1  Spaetzle - Basic Recipe - Art Culinaire Issue
# 2              Low-Fat Berry Blue Frozen Dessert
# 3                      Buttermilk Ranch Dressing
# 4         Low-Fat Burgundy Beef & Vegetable Stew
# 5                            Poseidon's Scallops
# 6                                   Cabbage Soup
# 7                 Brown Rice and Vegetable Pilaf
# 8                                Cafe Cappuccino
# 9              Appetizers-Easy Stuffed Mushrooms
#
#                                   RecipeInstructions  \
# 0  c("Wash potatoes under cold running water then...
# 1  c("Bring a saucepan of salted water it a boil,...
# 2  c("Toss 2 cups berries with sugar.", "Let stan...
# 3  c("Mash together garlic and salt to form a pas...
# 4  c("Trim fat from beef, cut into 1-inch pieces....
# 5  c("Chop ginger and garlic coarsely.", "Heat a ...
# ...

# %%
for i, j in recipes.iloc[0:3].iterrows():
    print(i, j)
# Out:
# 571 Name                                                          Bubble and Squeak
# RecipeInstructions            c("Wash potatoes under cold running water then...
# RecipeIngredientParts         c("baking potatoes", "unsalted butter", "heavy...
# RecipeIngredientQuantities    c("2", "2", "1/4", "4", "1/3", "1/2", "1", "1/...
# RecipeCategory                                                        Breakfast
# Images                                                             character(0)
# Calories                                                                  480.7
# FatContent                                                                 24.9
# SaturatedFatContent                                                        11.5
# CholesterolContent                                                         54.9
# SodiumContent                                                             286.1
# CarbohydrateContent                                                        56.9
# ...

# %%
recipes_df['RecipeIngredientParts'].sample(5)
# Out:
# 112181    ['tuna', 'celery', 'onion', 'walnuts', 'mayonn...
# 130565    ['boneless skinless chicken', 'chicken broth',...
# 95791     ['pineapple chunks in juice', 'apple', 'banana...
# 210584    ['vital wheat gluten flour', 'chickpea flour',...
# 221860    ['cabbage', 'bacon', 'egg', 'sugar', 'vinegar'...
# Name: RecipeIngredientParts, dtype: object
